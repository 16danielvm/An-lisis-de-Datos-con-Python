# %% [markdown]
# INDEXACION

# %%
#Importar librerias
import pandas as pd

# %%
pwd
# Out:
# 'd:\\Universidad\\Cursos\\Analisis de datos con Pandas'

# %%
#Carga dataset 'vehiculos.csv' en tabla
tabla = pd.read_csv('vehiculos.csv')

# %%
#Muestra el tipo de dato que es 'tabla.index'
type(tabla.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
tabla.index[22]
# Out:
# 22

# %%
#Muestra los primeros 30 datos de 'tabla'
tabla.head(30)
# Out:
#     compactness  circularity  distance_circularity  radius_ratio  \
# 0          95.0         48.0                  83.0         178.0
# 1          91.0         41.0                  84.0         141.0
# 2         104.0         50.0                 106.0         209.0
# 3          93.0         41.0                  82.0         159.0
# 4          85.0         44.0                  70.0         205.0
# 5         107.0         57.0                 106.0         172.0
# 6          97.0         43.0                  73.0         173.0
# 7          90.0         43.0                  66.0         157.0
# 8          86.0         34.0                  62.0         140.0
# 9          93.0         44.0                  98.0         197.0
# 10         86.0         36.0                  70.0         143.0
# 11         90.0         34.0                  66.0         136.0
# 12         88.0         46.0                  74.0         171.0
# ...

# %%
tablaCircularity = tabla.set_index('circularity') #Establece un nuevo indice

# %%
tablaCircularity
# Out:
#              compactness  distance_circularity  radius_ratio  \
# circularity
# 48.0                95.0                  83.0         178.0
# 41.0                91.0                  84.0         141.0
# 50.0               104.0                 106.0         209.0
# 41.0                93.0                  82.0         159.0
# 44.0                85.0                  70.0         205.0
# ...                  ...                   ...           ...
# 39.0                93.0                  87.0         183.0
# 46.0                89.0                  84.0         163.0
# 54.0               106.0                 101.0         222.0
# 36.0                86.0                  78.0         146.0
# 36.0                85.0                  66.0         123.0
#
#              pr_axis_aspect_ratio  max_length_aspect_ratio  scatter_ratio  \
# circularity
# 48.0                         72.0                     10.0          162.0
# ...

# %%
tablaCircularity.reset_index(inplace=True) #Resetea el indice

# %%
tablaCircularity
# Out:
#      circularity  compactness  distance_circularity  radius_ratio  \
# 0           48.0         95.0                  83.0         178.0
# 1           41.0         91.0                  84.0         141.0
# 2           50.0        104.0                 106.0         209.0
# 3           41.0         93.0                  82.0         159.0
# 4           44.0         85.0                  70.0         205.0
# ..           ...          ...                   ...           ...
# 841         39.0         93.0                  87.0         183.0
# 842         46.0         89.0                  84.0         163.0
# 843         54.0        106.0                 101.0         222.0
# 844         36.0         86.0                  78.0         146.0
# 845         36.0         85.0                  66.0         123.0
#
#      pr_axis_aspect_ratio  max_length_aspect_ratio  scatter_ratio  \
# 0                    72.0                     10.0          162.0
# ...

# %%
tablaCircularity = tabla.set_index('circularity')

# %%
tablaCircularity
# Out:
#              compactness  distance_circularity  radius_ratio  \
# circularity
# 48.0                95.0                  83.0         178.0
# 41.0                91.0                  84.0         141.0
# 50.0               104.0                 106.0         209.0
# 41.0                93.0                  82.0         159.0
# 44.0                85.0                  70.0         205.0
# ...                  ...                   ...           ...
# 39.0                93.0                  87.0         183.0
# 46.0                89.0                  84.0         163.0
# 54.0               106.0                 101.0         222.0
# 36.0                86.0                  78.0         146.0
# 36.0                85.0                  66.0         123.0
#
#              pr_axis_aspect_ratio  max_length_aspect_ratio  scatter_ratio  \
# circularity
# 48.0                         72.0                     10.0          162.0
# ...

# %%
#Ordena el indice
tablaCircularity.sort_index()
# Out:
#              compactness  distance_circularity  radius_ratio  \
# circularity
# 33.0                85.0                  50.0         104.0
# 33.0                85.0                  40.0         115.0
# 34.0                90.0                  66.0         158.0
# 34.0                88.0                  69.0         152.0
# 34.0                88.0                  58.0         140.0
# ...                  ...                   ...           ...
# 58.0               111.0                 105.0         183.0
# 58.0               104.0                 103.0         230.0
# 58.0               100.0                 109.0         230.0
# 58.0                98.0                 101.0         208.0
# 59.0                97.0                 108.0         227.0
#
#              pr_axis_aspect_ratio  max_length_aspect_ratio  scatter_ratio  \
# circularity
# 33.0                         53.0                      4.0          115.0
# ...

# %%
tablaCircularity.loc[48] #Busqueda por indice
# Out:
#              compactness  distance_circularity  radius_ratio  \
# circularity
# 48.0                95.0                  83.0         178.0
# 48.0               101.0                 107.0         222.0
# 48.0                90.0                  86.0         306.0
# 48.0                95.0                 104.0         214.0
# 48.0                94.0                  87.0         162.0
# 48.0                99.0                  79.0         199.0
# 48.0                94.0                  83.0         162.0
# 48.0                90.0                  78.0         142.0
# 48.0               100.0                  95.0         209.0
# 48.0                86.0                  75.0         136.0
# 48.0                93.0                  84.0         150.0
# 48.0                97.0                  94.0         198.0
# 48.0                90.0                  78.0         134.0
# 48.0                99.0                 104.0         196.0
# ...

# %%
tablaCircularity.iloc[34:89] #Busqueda por posicion
# Out:
#      195.0
# 39.0                         60.0                      8.0          172.0
# 40.0                         62.0                      7.0          150.0
# 52.0                         66.0                      5.0          208.0
# 44.0                         50.0                      7.0          150.0
# 46.0                         66.0                      6.0          151.0
# 51.0                         65.0                      5.0          209.0
# 36.0                         54.0                      7.0          127.0
# 40.0                         55.0                      7.0          147.0
# 40.0                         76.0                      7.0          150.0
# 58.0                         51.0                      6.0          261.0
# 41.0                         58.0                      9.0          149.0
# 37.0                         54.0                      5.0          119.0
# ...

# %% [markdown]
# AGRUPAR

# %%
tabla
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 0           95.0         48.0                  83.0         178.0
# 1           91.0         41.0                  84.0         141.0
# 2          104.0         50.0                 106.0         209.0
# 3           93.0         41.0                  82.0         159.0
# 4           85.0         44.0                  70.0         205.0
# ..           ...          ...                   ...           ...
# 841         93.0         39.0                  87.0         183.0
# 842         89.0         46.0                  84.0         163.0
# 843        106.0         54.0                 101.0         222.0
# 844         86.0         36.0                  78.0         146.0
# 845         85.0         36.0                  66.0         123.0
#
#      pr_axis_aspect_ratio  max_length_aspect_ratio  scatter_ratio  \
# 0                    72.0                     10.0          162.0
# ...

# %%
tabla.groupby('vehicle_class')

# %%
type(tabla.groupby('vehicle_class'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(tabla.groupby('vehicle_class'))
# Out:
#  12                   68.0                      6.0          152.0
#   14                   71.0                      5.0          174.0
#   ..                    ...                      ...            ...
#   814                  55.0                      7.0          150.0
#   815                  69.0                     22.0          151.0
#   830                  66.0                      7.0          151.0
#   831                  70.0                      7.0          162.0
#   835                  51.0                      6.0          265.0
#
#        elongatedness  pr_axis_rectangularity  max_length_rectangularity  \
#   4             45.0                    19.0                      144.0
#   5             26.0                    28.0                      169.0
#   6             42.0                    19.0                      143.0
#   12            43.0                    19.0                      148.0
# ...

# %%
for group_key, group_value in tabla.groupby('vehicle_class'):
    print(group_key)
    print(group_value)
# Out:
#          85.0         43.0                  66.0         123.0
# 815         81.0         45.0                  68.0         154.0
# 830         97.0         37.0                  70.0         173.0
# 831        100.0         47.0                  70.0         185.0
# 835        111.0         58.0                 105.0         183.0
#
#      pr_axis_aspect_ratio  max_length_aspect_ratio  scatter_ratio  \
# 4                   103.0                     52.0          149.0
# 5                    50.0                      6.0          255.0
# 6                    65.0                      6.0          153.0
# 12                   68.0                      6.0          152.0
# 14                   71.0                      5.0          174.0
# ..                    ...                      ...            ...
# 814                  55.0                      7.0          150.0
# 815                  69.0                     22.0          151.0
# ...

# %%
tabla.groupby('vehicle_class').size()
# Out:
# vehicle_class
# bus     218
# opel    212
# saab    217
# van     199
# dtype: int64

# %%
tabla.groupby('vehicle_class').size()
# Out:
# vehicle_class
# bus     218
# opel    212
# saab    217
# van     199
# dtype: int64

# %% [markdown]
# APILAR Y DESAPILAR FILAS

# %%
cat = tabla[(tabla.vehicle_class == 'van')]

# %%
cat
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 0           95.0         48.0                  83.0         178.0
# 1           91.0         41.0                  84.0         141.0
# 3           93.0         41.0                  82.0         159.0
# 7           90.0         43.0                  66.0         157.0
# 8           86.0         34.0                  62.0         140.0
# ..           ...          ...                   ...           ...
# 836         87.0         45.0                  66.0         139.0
# 838         95.0         43.0                  76.0         142.0
# 839         90.0         44.0                  72.0         157.0
# 842         89.0         46.0                  84.0         163.0
# 845         85.0         36.0                  66.0         123.0
#
#      pr_axis_aspect_ratio  max_length_aspect_ratio  scatter_ratio  \
# 0                    72.0                     10.0          162.0
# ...

# %%
c = cat.groupby(['compactness', 'circularity']).size()

# %%
c
# Out:
# compactness  circularity
# 82.0         43.0           1
# 83.0         37.0           2
#              40.0           2
#              45.0           1
# 84.0         37.0           3
#                            ..
# 97.0         47.0           1
# 98.0         38.0           2
#              39.0           2
#              44.0           2
# 100.0        46.0           2
# Length: 118, dtype: int64

# %%
c.unstack('circularity')
# Out:
# circularity  34.0  35.0  36.0  37.0  38.0  39.0  40.0  41.0  42.0  43.0  44.0  \
# compactness
# 82.0          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   1.0   NaN
# 83.0          NaN   NaN   NaN   2.0   NaN   NaN   2.0   NaN   NaN   NaN   NaN
# 84.0          NaN   NaN   NaN   3.0   NaN   NaN   NaN   NaN   NaN   NaN   1.0
# 85.0          NaN   2.0   2.0   1.0   NaN   2.0   NaN   NaN   NaN   NaN   NaN
# 86.0          1.0   1.0   1.0   2.0   2.0   3.0   1.0   NaN   NaN   1.0   1.0
# 87.0          NaN   NaN   1.0   1.0   NaN   NaN   1.0   NaN   2.0   NaN   NaN
# 88.0          1.0   1.0   1.0   1.0   NaN   1.0   1.0   1.0   2.0   1.0   2.0
# 89.0          NaN   1.0   3.0   1.0   1.0   NaN   4.0   2.0   3.0   1.0   2.0
# 90.0          NaN   NaN   NaN   NaN   NaN   1.0   NaN   1.0   1.0   3.0   2.0
# 91.0          NaN   NaN   1.0   1.0   1.0   2.0   NaN   3.0   2.0   2.0   1.0
# 92.0          NaN   1.0   NaN   NaN   1.0   NaN   3.0   1.0   NaN   1.0   NaN
# ...
